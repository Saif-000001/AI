# %%
# Import Dependencies 
import tensorflow_hub as hub
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np 
import cv2
# Out:
# 2024-02-27 12:54:28.516885: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-27 12:54:28.516918: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-27 12:54:28.518135: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-27 12:54:28.525039: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-27 12:54:29.341664: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Pretrained Model and Load TF Hub module
hub_handle = 'https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2'
model = hub.load(hub_handle)

# %%
# Preprocess Image 
def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img[tf.newaxis, :]
    return img

# %%
# load image 
content_img = load_img('IMG_0324.jpg')
style_img = load_img('style.jpeg')
# Out:
# 2024-02-27 12:54:32.175247: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 146313216 exceeds 10% of free system memory.
# 2024-02-27 12:54:32.203576: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 146313216 exceeds 10% of free system memory.

# %%
# Visualize Output  
content_img.shape
# Out:
# TensorShape([1, 3024, 4032, 3])

# %%
plt.imshow(np.squeeze(content_img))

# %%
plt.imshow(np.squeeze(style_img))
plt.show()

# %%
# Stylize Image 
output= model(tf.constant(content_img), tf.constant(style_img))
stylize_img = output[0]

# %%
plt.imshow(np.squeeze(stylize_img))
plt.show()

# %%
cv2.imwrite('generated_img.jpg', cv2.cvtColor(np.squeeze(stylize_img)*255, cv2.COLOR_BGR2RGB))
